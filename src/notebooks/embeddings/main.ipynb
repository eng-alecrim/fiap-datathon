# %%
from custom_nlp.embedding import (
    create_word2vec,
    SentenceTransformerEmbeddingStrategy,
    EmbeddingModel,
)

# %%
embedding_model = EmbeddingModel()
embedding_model.set_strategy(SentenceTransformerEmbeddingStrategy())

# %%
embedding_model.create_embedding(text="This is a test sentence.")
# Out:
# array([ 3.96986492e-02,  9.99478623e-02,  4.95042056e-02,  1.10761710e-02,
#        -4.64506559e-02,  3.62440273e-02,  1.39316740e-02, -3.03604640e-02,
#        -2.80023199e-02, -1.50574120e-02,  2.41408553e-02, -2.29196176e-02,
#         1.64338797e-02, -6.81718290e-02, -8.74510780e-02, -3.85978892e-02,
#         2.81845760e-02, -1.45200446e-01,  5.61486371e-03,  3.32252160e-02,
#         7.76698813e-02, -2.56981235e-02,  3.70214880e-02,  6.15097284e-02,
#        -3.24913673e-02,  2.59788651e-02,  3.57660428e-02, -5.09662516e-02,
#         3.41030359e-02, -8.56219307e-02,  9.29859374e-03,  1.26402348e-01,
#         4.65535410e-02,  1.38269980e-02,  2.77773687e-03, -3.60262790e-03,
#        -3.92303690e-02, -1.80561822e-02,  1.14478059e-02,  9.96659044e-03,
#        -1.18722925e-02, -6.82047307e-02,  5.65148741e-02,  4.82538044e-02,
#         2.45855395e-02,  1.82100870e-02,  7.43979290e-02, -7.29504135e-03,
# ...
